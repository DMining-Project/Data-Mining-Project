# %% [markdown]
# # Imports:

# %%
import sqlite3
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from sklearn.impute import KNNImputer
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from pandas_profiling import ProfileReport 

# %matplotlib inline
sns.set()

from math import ceil

# %% [markdown]
# # Reading the Data:

# %%
df = pd.read_csv('donors.csv', header=0, index_col=[0,'CONTROLN'], low_memory=False, 
                 dtype={'TCODE':'str','HPHONE_D':'str','RFA_2F':'str','WEALTH1':'str','WEALTH2':'str','INCOME':'str'})
df.head()
# Out:
#                ODATEDW OSOURCE TCODE STATE    ZIP MAILCODE PVASTATE  \
#   CONTROLN
# 0 95515     2009-01-01     GRI     0    IL  61081
# 1 148535    2014-01-01     BOA     1    CA  91326
# 2 15078     2010-01-01     AMH     1    NC  27017
# 3 172556    2007-01-01     BRY     0    CA  95953
# 4 7112      2006-01-01             0    FL  33176
#
#                    DOB NOEXCH RECINHSE  ... TIMELAG    AVGGIFT HPHONE_D  \
#   CONTROLN                              ...
# 0 95515     1957-12-01      0           ...     4.0   7.741935        0
# 1 148535    1972-02-01      0           ...    18.0  15.666667        0
# 2 15078            NaN      0           ...    12.0   7.481481        1
# 3 172556    1948-01-01      0           ...     9.0   6.812500        1
# 4 7112      1940-01-01      0        X  ...    14.0   6.864865        1
#
#            RFA_2R RFA_2F RFA_2A MDMAUD_R MDMAUD_F MDMAUD_A GEOCODE2
#   CONTROLN
# 0 95515         L      4      E        X        X        X        C
# 1 148535        L      2      G        X        X        X        A
# 2 15078         L      4      E        X        X        X        C
# 3 172556        L      4      E        X        X        X        C
# 4 7112          L      2      F        X        X        X        A
#
# [5 rows x 474 columns]

# %% [markdown]
# # Initial analysis

# %%
# check df data types:
df.dtypes
# Out:
# ODATEDW     object
# OSOURCE     object
# TCODE       object
# STATE       object
# ZIP         object
#              ...
# RFA_2A      object
# MDMAUD_R    object
# MDMAUD_F    object
# MDMAUD_A    object
# GEOCODE2    object
# Length: 474, dtype: object

# %%
# replace "" by nans:
df.replace("", np.nan, inplace=True)

# %%
# checking descriptive statistics:
df.describe(include="all").T

# %% [markdown]
# # Missing Values:

# %%
# sorted count of missing values:
df.isnull().sum()[df.isnull().sum()>0].sort_values(ascending=False)
